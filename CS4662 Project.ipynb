# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt
img=mpimg.imread('/Users/perinshah/Downloads/imgs/train/c0/img_34.jpg')
plt.imshow(img, cmap=plt.cm.gray_r, interpolation='nearest')

# %%
#Do not run

import os
feature=[]
label =[]
BASE_DIR = '/Users/perinshah/Downloads/imgs/'
train_folder = BASE_DIR+'train/'
label_c0 = train_folder+'c0'
label_c2 = train_folder+'c2'
label_c6 = train_folder+'c6'
label_c7 = train_folder+'c7'

images_in_c0 = sorted(os.listdir(label_c0))

#images_in_c2 = sorted(os.listdir(label_c2))
#images_in_c6 = sorted(os.listdir(label_c6))
#images_in_c7 = sorted(os.listdir(label_c7))

for img in images_in_c0: 
    row = np.reshape(img, (640 * 480))
    feature.append(row)
    label.append(0)
label_c0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8a63db3d98cb> in <module>
#      16
#      17 for img in images_in_c0:
# ---> 18     row = np.reshape(img, (640 * 480))
#      19     feature.append(row)
#      20     label.append(0)
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     299            [5, 6]])
#     300     """
# --> 301     return _wrapfunc(a, 'reshape', newshape, order=order)
#     302
#     303
#
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ...

# %%
#Do not run
feature=[]
label =[]
folder= mpimg.imread('/Users/perinshah/Downloads/imgs/train/c0')
for img in folder:
    #try:
    #    img=mpimg.imread('/Users/perinshah/Downloads/imgs/train/c0/img_%d.jpg'%i)
    #expect RuntimeError:
     #   i++
        
    row = np.reshape(img, (640 * 480))
    feature.append(row)
    label.append(0)

# %%
feature=[]
label =[]
#img=mpimg.imread('/Users/perinshah/Downloads/imgs/train/c0')
for i in  range(34, 102088):
    try:
        img = mpimg.imread('/Users/perinshah/Downloads/imgs/train/c0/img_%d.jpg'%i)
    except OSError as e :
        i+=1
        
    row = np.reshape(img, (3 * 640 * 480))
    feature.append(row)
    label.append("c0")
    
for i in range(34, 102088):
    try:
        img=mpimg.imread('/Users/perinshah/Downloads/imgs/train/c2/img_%d.jpg'%i)
    except OSError as e:
        i+=1
        
    row = np.reshape(img, (3 * 640 * 480))
    feature.append(row)
    label.append("c2")
    
for i in range(34, 102088):
    try:
        img=mpimg.imread('/Users/perinshah/Downloads/imgs/train/c6/img_%d.jpg'%i)
    except OSError as e:
        i+=1
        
    row = np.reshape(img, (3 * 640 * 480))
    feature.append(row)
    label.append("c6")

for i in range(34, 102088):
    try:
        img=mpimg.imread('/Users/perinshah/Downloads/imgs/train/c7/img_%d.jpg'%i)
    except OSError as e:
        i+=1
        
    row = np.reshape(img, (3 * 640 * 480))
    feature.append(row)
    label.append("c7")

df = pd.DataFrame(feature)
#labels=pd.read_csv('/Users/perinshah/HW5/label.csv')
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5b17f336e6d1> in <module>
#      42     label.append("c7")
#      43
# ---> 44 df=pd.DataFrame(feature)
#      45 #labels=pd.read_csv('/Users/perinshah/HW5/label.csv')
#      46 df
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     486         # last ditch effort
# ...

# %%
#Preprocessing
y = label

X_train = preprocessing.scale(df)

# %%
# One hot encoding
y = np_utils.to_categorical(y, 4)
